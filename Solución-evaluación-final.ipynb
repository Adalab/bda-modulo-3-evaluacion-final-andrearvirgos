# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# Crear carpeta "images" si no existe
if not os.path.exists("images"):
    os.makedirs("images")

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Carga y exploración inicial:

# %%
df_history = pd.read_csv("data/Customer Loyalty History.csv") 
#primera exploración visual
df_history
# Out:
#        Loyalty Number Country          Province        City Postal Code  \
# 0              480934  Canada           Ontario     Toronto     M2Z 4K1
# 1              549612  Canada           Alberta    Edmonton     T3G 6Y6
# 2              429460  Canada  British Columbia   Vancouver     V6E 3D9
# 3              608370  Canada           Ontario     Toronto     P1W 1K4
# 4              530508  Canada            Quebec        Hull     J8Y 3Z5
# ...               ...     ...               ...         ...         ...
# 16732          823768  Canada  British Columbia   Vancouver     V6E 3Z3
# 16733          680886  Canada      Saskatchewan      Regina     S1J 3C5
# 16734          776187  Canada  British Columbia   Vancouver     V5R 1W3
# 16735          906428  Canada             Yukon  Whitehorse     Y2K 6R0
# 16736          652627  Canada          Manitoba    Winnipeg     R2C 0M5
#
#        Gender Education    Salary Marital Status Loyalty Card       CLV  \
# 0      Female  Bachelor   83236.0        Married         Star   3839.14
# 1        Male   College       NaN       Divorced         Star   3839.61
# 2        Male   College       NaN         Single         Star   3839.75
# 3        Male   College       NaN         Single         Star   3839.75
# 4        Male  Bachelor  103495.0        Married         Star   3842.79
# ...       ...       ...       ...            ...          ...       ...
# 16732  Female   College       NaN        Married         Star  61850.19
# 16733  Female  Bachelor   89210.0        Married         Star  67907.27
# 16734    Male   College       NaN         Single         Star  74228.52
# 16735    Male  Bachelor  -57297.0        Married         Star  10018.66
# 16736  Female  Bachelor   75049.0        Married         Star  83325.38
#
#       Enrollment Type  Enrollment Year  Enrollment Month  Cancellation Year  \
# 0            Standard             2016                 2                NaN
# 1            Standard             2016                 3                NaN
# 2            Standard             2014                 7             2018.0
# 3            Standard             2013                 2                NaN
# 4            Standard             2014                10                NaN
# ...               ...              ...               ...                ...
# 16732        Standard             2012                12                NaN
# 16733        Standard             2014                 9                NaN
# 16734        Standard             2014                 3                NaN
# 16735  2018 Promotion             2018                 4                NaN
# 16736        Standard             2015                12             2016.0
#
#        Cancellation Month
# 0                     NaN
# 1                     NaN
# 2                     1.0
# 3                     NaN
# 4                     NaN
# ...                   ...
# 16732                 NaN
# 16733                 NaN
# 16734                 NaN
# 16735                 NaN
# 16736                 8.0
#
# [16737 rows x 16 columns]

# %%
df_history.tail()
# Out:
#        Loyalty Number Country          Province        City Postal Code  \
# 16732          823768  Canada  British Columbia   Vancouver     V6E 3Z3
# 16733          680886  Canada      Saskatchewan      Regina     S1J 3C5
# 16734          776187  Canada  British Columbia   Vancouver     V5R 1W3
# 16735          906428  Canada             Yukon  Whitehorse     Y2K 6R0
# 16736          652627  Canada          Manitoba    Winnipeg     R2C 0M5
#
#        Gender Education   Salary Marital Status Loyalty Card       CLV  \
# 16732  Female   College      NaN        Married         Star  61850.19
# 16733  Female  Bachelor  89210.0        Married         Star  67907.27
# 16734    Male   College      NaN         Single         Star  74228.52
# 16735    Male  Bachelor -57297.0        Married         Star  10018.66
# 16736  Female  Bachelor  75049.0        Married         Star  83325.38
#
#       Enrollment Type  Enrollment Year  Enrollment Month  Cancellation Year  \
# 16732        Standard             2012                12                NaN
# 16733        Standard             2014                 9                NaN
# 16734        Standard             2014                 3                NaN
# 16735  2018 Promotion             2018                 4                NaN
# 16736        Standard             2015                12             2016.0
#
#        Cancellation Month
# 16732                 NaN
# 16733                 NaN
# 16734                 NaN
# 16735                 NaN
# 16736                 8.0

# %%
df_history.sample(5)
# Out:
#        Loyalty Number Country          Province         City Postal Code  \
# 9890           187902  Canada     New Brunswick  Fredericton     E3B 2H2
# 3339           720131  Canada  British Columbia     Whistler     V6T 1Y8
# 5946           204237  Canada  British Columbia    Vancouver     V6E 3D9
# 13788          106964  Canada     New Brunswick      Moncton     E1A 2A7
# 9068           272848  Canada      Saskatchewan       Regina     S6J 3G0
#
#        Gender Education   Salary Marital Status Loyalty Card       CLV  \
# 9890     Male   College      NaN         Single         Star   2141.98
# 3339   Female  Bachelor  96550.0        Married       Aurora  12280.77
# 5946     Male   College      NaN         Single         Nova   4595.04
# 13788  Female   College      NaN         Single         Star   5568.95
# 9068     Male  Bachelor  71922.0        Married         Nova  13167.61
#
#       Enrollment Type  Enrollment Year  Enrollment Month  Cancellation Year  \
# 9890         Standard             2017                 4                NaN
# 3339         Standard             2018                11                NaN
# 5946         Standard             2016                 1             2018.0
# 13788        Standard             2018                 8                NaN
# 9068         Standard             2018                 7                NaN
#
#        Cancellation Month
# 9890                  NaN
# 3339                  NaN
# 5946                  3.0
# 13788                 NaN
# 9068                  NaN

# %%
df_history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16737 entries, 0 to 16736
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Loyalty Number      16737 non-null  int64
#  1   Country             16737 non-null  object
#  2   Province            16737 non-null  object
#  3   City                16737 non-null  object
#  4   Postal Code         16737 non-null  object
#  5   Gender              16737 non-null  object
#  6   Education           16737 non-null  object
#  7   Salary              12499 non-null  float64
#  8   Marital Status      16737 non-null  object
#  9   Loyalty Card        16737 non-null  object
#  10  CLV                 16737 non-null  float64
#  11  Enrollment Type     16737 non-null  object
#  12  Enrollment Year     16737 non-null  int64
#  13  Enrollment Month    16737 non-null  int64
#  14  Cancellation Year   2067 non-null   float64
#  15  Cancellation Month  2067 non-null   float64
# dtypes: float64(4), int64(3), object(9)
# memory usage: 2.0+ MB

# %%
df_activity = pd.read_csv("data/Customer Flight Activity.csv")
df_activity
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0               100018  2017      1               3                        0
# 1               100102  2017      1              10                        4
# 2               100140  2017      1               6                        0
# 3               100214  2017      1               0                        0
# 4               100272  2017      1               0                        0
# ...                ...   ...    ...             ...                      ...
# 405619          999902  2018     12               0                        0
# 405620          999911  2018     12               0                        0
# 405621          999940  2018     12               3                        0
# 405622          999982  2018     12               0                        0
# 405623          999986  2018     12               0                        0
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0                   3      1521               152.0                0
# 1                  14      2030               203.0                0
# 2                   6      1200               120.0                0
# 3                   0         0                 0.0                0
# 4                   0         0                 0.0                0
# ...               ...       ...                 ...              ...
# 405619              0         0                 0.0                0
# 405620              0         0                 0.0                0
# 405621              3      1233               123.0                0
# 405622              0         0                 0.0                0
# 405623              0         0                 0.0                0
#
#         Dollar Cost Points Redeemed
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                 0
# 4                                 0
# ...                             ...
# 405619                            0
# 405620                            0
# 405621                            0
# 405622                            0
# 405623                            0
#
# [405624 rows x 10 columns]

# %%
df_activity.tail()
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 405619          999902  2018     12               0                        0
# 405620          999911  2018     12               0                        0
# 405621          999940  2018     12               3                        0
# 405622          999982  2018     12               0                        0
# 405623          999986  2018     12               0                        0
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 405619              0         0                 0.0                0
# 405620              0         0                 0.0                0
# 405621              3      1233               123.0                0
# 405622              0         0                 0.0                0
# 405623              0         0                 0.0                0
#
#         Dollar Cost Points Redeemed
# 405619                            0
# 405620                            0
# 405621                            0
# 405622                            0
# 405623                            0

# %%
df_activity.sample(5) # al ejecutar varias veces la celda, que las columnas de Points Redeemed y Dollar Cost Points Redeemed sus valores son 0 en casi todas las filas
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 237174          706962  2017      4               6                        6
# 27937           160779  2018      5               0                        0
# 190646          486860  2018     10               3                        2
# 139119          309727  2017      9               6                        0
# 29820           785223  2017      2               4                        0
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 237174             12      2496               249.0              563
# 27937               0         0                 0.0                0
# 190646              5      2610               261.0              588
# 139119              6       696                69.0                0
# 29820               4      1440               144.0                0
#
#         Dollar Cost Points Redeemed
# 237174                           46
# 27937                             0
# 190646                           48
# 139119                            0
# 29820                             0

# %%
df_activity.info() # ¿por qué ésto me devuelve solo 9 cols y no 10?¿dónde está la col loyalty number?
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405624 entries, 0 to 405623
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Loyalty Number               405624 non-null  int64
#  1   Year                         405624 non-null  int64
#  2   Month                        405624 non-null  int64
#  3   Flights Booked               405624 non-null  int64
#  4   Flights with Companions      405624 non-null  int64
#  5   Total Flights                405624 non-null  int64
#  6   Distance                     405624 non-null  int64
#  7   Points Accumulated           405624 non-null  float64
#  8   Points Redeemed              405624 non-null  int64
#  9   Dollar Cost Points Redeemed  405624 non-null  int64
# dtypes: float64(1), int64(9)
# memory usage: 30.9 MB

# %%
df_history.isna().sum() 
#ojo a las columnas CancellationYear y Month, que tienen ambas 14670 nulos, frente al total de 16737! (en esas columnas solo hay 2067 valores no nulos)
# Salary también tiene un recuento de nulos significativo.
# Out:
# Loyalty Number            0
# Country                   0
# Province                  0
# City                      0
# Postal Code               0
# Gender                    0
# Education                 0
# Salary                 4238
# Marital Status            0
# Loyalty Card              0
# CLV                       0
# Enrollment Type           0
# Enrollment Year           0
# Enrollment Month          0
# Cancellation Year     14670
# Cancellation Month    14670
# dtype: int64

# %%
round(df_history.isna().sum()/df_history.shape[0]*100,2)
# Out:
# Loyalty Number         0.00
# Country                0.00
# Province               0.00
# City                   0.00
# Postal Code            0.00
# Gender                 0.00
# Education              0.00
# Salary                25.32
# Marital Status         0.00
# Loyalty Card           0.00
# CLV                    0.00
# Enrollment Type        0.00
# Enrollment Year        0.00
# Enrollment Month       0.00
# Cancellation Year     87.65
# Cancellation Month    87.65
# dtype: float64

# %%
df_activity.isna().sum()
# Out:
# Loyalty Number                 0
# Year                           0
# Month                          0
# Flights Booked                 0
# Flights with Companions        0
# Total Flights                  0
# Distance                       0
# Points Accumulated             0
# Points Redeemed                0
# Dollar Cost Points Redeemed    0
# dtype: int64

# %%
round(df_activity.isna().sum()/df_activity.shape[0]*100,2)
# No hay valores nulos!
# Out:
# Loyalty Number                 0.0
# Year                           0.0
# Month                          0.0
# Flights Booked                 0.0
# Flights with Companions        0.0
# Total Flights                  0.0
# Distance                       0.0
# Points Accumulated             0.0
# Points Redeemed                0.0
# Dollar Cost Points Redeemed    0.0
# dtype: float64

# %%
df_activity.describe().T
# Out:
#                                 count           mean            std       min  \
# Loyalty Number               405624.0  550037.873084  258935.286969  100018.0
# Year                         405624.0    2017.500000       0.500001    2017.0
# Month                        405624.0       6.500000       3.452057       1.0
# Flights Booked               405624.0       4.115052       5.225518       0.0
# Flights with Companions      405624.0       1.031805       2.076869       0.0
# Total Flights                405624.0       5.146858       6.521227       0.0
# Distance                     405624.0    1208.880059    1433.155320       0.0
# Points Accumulated           405624.0     123.692721     146.599831       0.0
# Points Redeemed              405624.0      30.696872     125.486049       0.0
# Dollar Cost Points Redeemed  405624.0       2.484503      10.150038       0.0
#
#                                    25%       50%        75%       max
# Loyalty Number               326961.00  550834.0  772194.00  999986.0
# Year                           2017.00    2017.5    2018.00    2018.0
# Month                             3.75       6.5       9.25      12.0
# Flights Booked                    0.00       1.0       8.00      21.0
# Flights with Companions           0.00       0.0       1.00      11.0
# Total Flights                     0.00       1.0      10.00      32.0
# Distance                          0.00     488.0    2336.00    6293.0
# Points Accumulated                0.00      50.0     239.00     676.5
# Points Redeemed                   0.00       0.0       0.00     876.0
# Dollar Cost Points Redeemed       0.00       0.0       0.00      71.0

# %%
df_history.describe().T
# Out:
#                       count           mean            std        min  \
# Loyalty Number      16737.0  549735.880445  258912.132453  100018.00
# Salary              12499.0   79245.609409   35008.297285  -58486.00
# CLV                 16737.0    7988.896536    6860.982280    1898.01
# Enrollment Year     16737.0    2015.253211       1.979111    2012.00
# Enrollment Month    16737.0       6.669116       3.398958       1.00
# Cancellation Year    2067.0    2016.503145       1.380743    2013.00
# Cancellation Month   2067.0       6.962748       3.455297       1.00
#
#                           25%        50%        75%        max
# Loyalty Number      326603.00  550434.00  772019.00  999986.00
# Salary               59246.50   73455.00   88517.50  407228.00
# CLV                   3980.84    5780.18    8940.58   83325.38
# Enrollment Year       2014.00    2015.00    2017.00    2018.00
# Enrollment Month         4.00       7.00      10.00      12.00
# Cancellation Year     2016.00    2017.00    2018.00    2018.00
# Cancellation Month       4.00       7.00      10.00      12.00

# %%
df_history.describe(include="O").T  # en este df incluimos los objetos, para que nos devuelva un recuento de lo que no está calculando en el describe anterior que solo computa las variables numéricas.
#¿Aerolínea canadiense maybe?
# Out:
#                  count unique       top   freq
# Country          16737      1    Canada  16737
# Province         16737     11   Ontario   5404
# City             16737     29   Toronto   3351
# Postal Code      16737     55   V6E 3D9    911
# Gender           16737      2    Female   8410
# Education        16737      5  Bachelor  10475
# Marital Status   16737      3   Married   9735
# Loyalty Card     16737      3      Star   7637
# Enrollment Type  16737      2  Standard  15766

# %% [markdown]
# ### T

# %%
def archivar_grafica(nombre):
    ruta = f"images/{nombre}.png"
    plt.savefig(ruta, dpi=300, bbox_inches="tight")
    print(f" Gráfica archivada en: {ruta}")

# %%
# visual rápida de los 2 df: 

df_history

# %%
# NO EJECUTAR AÚN! 
# FASE DE VISUALIZACIONES (pegar esto cada vez que haga una gráfica):

# código para pegar al crear gráfica y que se ejecuten conjuntamente, para archivar directamente la imagen.
plt.figure(figsize=(10,6))
sns.barplot(data=df, x="Month", y="Flights Booked")
plt.title("Vuelos por mes")

plt.plot(x, y)
archivar_grafica("grafica_ejemplo")
plt.show()
